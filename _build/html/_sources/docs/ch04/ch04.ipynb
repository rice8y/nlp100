# %% [markdown]
# # 第4章: 形態素解析
# 夏目漱石の小説『吾輩は猫である』の文章 ([neko.txt](https://nlp100.github.io/data/neko.txt)) をMeCabを使って形態素解析し, その結果をneko.txt.mecabというファイルに保存せよ. このファイルを用いて, 以下の問に対応するプログラムを実装せよ.
#
# なお, 問題37, 38, 39は[matplotlib](http://matplotlib.org/)もしくは[Gnuplot](http://www.gnuplot.info/)を用いるとよい.

# %% [markdown]
# ## 30. 形態素解析結果の読み込み
# 形態素解析結果 (neko.txt.mecab) を読み込むプログラムを実装せよ. ただし, 各形態素は表層形 (surface), 基本形 (base), 品詞 (pos), 品詞細分類1 (pos1) をキーとするマッピング型に格納し, 1文を形態素 (マッピング型) のリストとして表現せよ. 第4章の残りの問題では, ここで作ったプログラムを活用せよ.

# %%
import MeCab

mecab = MeCab.Tagger()
with open("neko.txt", "r") as f1, open("neko.txt.mecab", "w+") as f2:
    lines = f1.readlines()
    for text in lines:
        result = mecab.parse(text)
        f2.write(result)

# %%
with open("neko.txt.mecab", "r") as f:
    lines = f.readlines()
    nlist = []
    for text in lines:
        ndict = {}
        suf = text.split("\t")
        if suf[0] == "EOS":
            continue
        if len(suf) > 1:
            tmp = suf[1].split(",")
            ndict["surface"] = suf[0]
            if len(tmp) <= 7:
                ndict["base"] = suf[0]
            else:
                ndict["base"] = tmp[7]
            ndict["pos"] = tmp[0]
            ndict["pos1"] = tmp[1]
            nlist.append(ndict)
            
for item in nlist[:10]: # Due to file size constraints, the output is limited.
    print(item)
# Out:
# {'surface': '一', 'base': '一', 'pos': '名詞', 'pos1': '数詞'}
# {'surface': '\u3000', 'base': '\u3000', 'pos': '空白', 'pos1': ''}
# {'surface': '吾輩', 'base': '我が輩', 'pos': '代名詞', 'pos1': ''}
# {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'}
# {'surface': '猫', 'base': '猫', 'pos': '名詞', 'pos1': '普通名詞'}
# {'surface': 'で', 'base': 'だ', 'pos': '助動詞', 'pos1': ''}
# {'surface': 'ある', 'base': '有る', 'pos': '動詞', 'pos1': '非自立可能'}
# {'surface': '。', 'base': '。', 'pos': '補助記号', 'pos1': '句点'}
# {'surface': '名前', 'base': '名前', 'pos': '名詞', 'pos1': '普通名詞'}
# {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'}

# %% [markdown]
# ## 31. 動詞
# 動詞の表層形をすべて抽出せよ.

# %%
verbs = {item["surface"] for item in nlist if item["pos"] == "動詞"}
print(verbs)
# Out:
# {'仆れる', 'こぼれ', '冷え', 'けり', '自惚れ', '引き上げる', '上す', '片付く', 'はじめる', '襲う', '経っ', '咲い', 'いっ', '叶わ', 'めさ', '飛び降りる', '下さっ', 'かかっ', '強', '損ね', '見知り', 'もとづく', '任ずる', '送', '承り', '煩わし', '潰し', '壊し', '取り着か', 'さておい', '具え', 'つかまっ', '有る', 'うる', '湧き出る', '書い', '見積っ', '立ち寄っ', '心づか', '犯さ', '引き揚げ', 'ぶんなぐる', '結びつけ', 'だい', '順っ', '激し', '省い', '改め', '噛ま', '抛り出す', '見よう', '巡り', '添う', '向が', '憚り', 'やむ', '殺せ', 'こせつい', '関し', 'つれ', '脱する', 'ふり上げる', '入る', 'もっ', '踏ん', '保っ', '尾け', '供し', '離す', '逃げ延び', 'じらせる', '裂き', '取り去る', 'からかい', '遠ざかる', 'きか', '飽き足ら', '使い', '負え', '騒ぎ立て', 'つかれ', '揺れ', '進め', '喰う', 'かくす', '披い', '参り', '被れ', '付ける', '有ん', 'くるみ込む', '狂っ', '聞き返し', '蘇える', 'つっかけ', '捏ね', '引きくらべ', '試し', '寄せる', '損い', '出よう', '嚇し', 'ぶら下っ', '参っ', '突き立て', '晴れ', '掛け', '困らし', '祝す', '突い', '奏し', '差し', 'とまら', '作っ', '奢り', '刈っ', '払っ', '起き上がる', '申し込ま', '握っ', '打ちつけ', 'ごまかし', '見つかり', '利かし', 'かたちづくっ', 'おる', '恋い', '頑張っ', '食いつく', '掻い', '加え', '死な', '捉まる', '迷わさ', '引張る', '離れ', '追い懸ける', '張り付け', '抱く', 'くり込ん', '落ちる', '引っ掛け', '釣れ', '見做さ', '垂れる', 'でき', 'かる', '曲る', '争う', '動じ', '亡くなり', '溶かし込ん', '剃っ', '流れ込む', '引きあげる', 'わかり', '転ずる', '癒る', '経', 'やっつけ', '従え', '尽し', 'くらさ', '攫ん', '勝とう', '立ち', '詰め寄せる', '逃げ込む', '仰せつけ', '聞きつけ', '釣り合わ', '跳ね返し', '崇め', '頂い', 'もとめ', '平伏し', '響く', '引き付け', '食う', '立ち上がっ', '説き聞かし', '盛っ', '就く', 'あきらめ', '住め', '説く', 'いらっしゃい', '清め', '回らす', '明い', '撚り', '重んぜ', '見つかる', '揉み潰そう', '浴し', 'あやまっ', 'もぐる', '絞る', 'つる', '重なっ', '奮っ', '混ぜ', '寝転ぶ', '化する', '歩行く', '視る', '叩き', '名乗る', '考え出そう', '直さ', '卸す', '巫山戯', '化す', '照らし', '弱り', '語ら', '上っ', '踏み込ん', 'はなす', '切る', '頼み', '煎じ', 'いわ', '歩き', 'しっ', '労ら', '抛り込ん', '無くなっ', '了れ', '突き込ん', '拵らえ', 'きら', '救い出し', 'すく', '点じ', '掛る', '受け合え', 'いたす', 'しまい込ん', '着せ', 'あつまっ', '打つ', 'とまる', '戒め', '厭き', '見えよう', '表し', 'たっ', 'ぶら下げる', 'はぐっ', '覚っ', '伝わる', '並べ', '眠れ', '降っ', '拭く', '然', '言い', 'くるみ', '捻る', 'たた', 'かなっ', '置こう', 'できる', '刈り込ま', '忍ん', '突っ伏し', '擦り付け', '注す', '当て', '弄する', 'すい', '得よう', '対し', '称え', '躍る', '逼る', '垂らす', '騒ぎ', '欲する', '償おう', '欠い', '癒り', '翳す', '弾く', '持ち', '廻り', '彫り付け', 'ぶっ切ら', '飛び込め', '言いあらわせ', '置ける', '澄し', '忌み嫌っ', 'から', '聞え', '立てる', '廻れ', 'つきつける', 'おけ', '突き付け', '着し', '講ずる', '撞く', '弾き出す', '移る', '生れる', 'いこう', '燃える', '挑む', '能い', '盛り込ま', '写し', '数え立て', '促し', '事足る', '心掛け', '傾く', 'よし', '似あう', '決せ', 'かかり', '斃れ', '話せ', '結い繞らせ', '心得', '抓ま', '擦る', '繰り返し', 'とりかかる', '叶っ', '読ま', '見出す', '考え出し', '召し上がら', '願おう', '叱し', 'つい', '嫌っ', '引っ張ら', '控える', '禿げ', '起き', '食み出し', '堪り', '吠え', '立ち行く', '振り撒い', '有す', '云い切り', '剥げ', '怠っ', '違い', '受', '遂げ', '免がれ', '見合せ', 'やみ', '持て', '出で', '陥れる', 'ぬくもっ', 'もらえ', '弁じ立てる', '訳し', '解い', 'よそう', '待ち受け', '着換え', 'かたどっ', '障り', '食っ', '戻っ', 'かわれる', '詠ん', '見え', '潜り', '掻い込ん', '張る', '蒙ろう', 'うかがっ', 'ふくれ返っ', '引きずっ', '罹る', '飛び下りる', '投げ込ん', '刎ね上げ', '押し合っ', '持ち切っ', '詫び入る', '浴びる', '談じ', 'わかし', 'とめ', 'あてがえ', '使え', '動き', '拵え', '突き廻さ', '抓ん', '置か', '乱れ合う', '逆立て', '取り上げ', '偸み', '鍛え上げ', '酬い', 'おっ', '受け', '送る', '持っ', '怺え', '撓め', '動かし', '暮れれ', '穿く', '祝う', '冒し', '飲み下し', '見捨て', '泊っ', 'いがみ合い', '呑む', 'さげ', '説い', '期し', '縊れる', '離れる', '守る', '振い落す', 'つまる', '突き', '了し', '上がろう', '外し', '欺す', '申し渡し', '係わる', 'なぐりつける', 'おくっ', '使う', '取り立て', 'あげ', '帯び', '飛ばし', 'とっ', '困ら', '向っ', '食おう', '行', '決める', '入れ代っ', '見せ', '包み', '恐る', '乞わ', 'おこせ', '逆らわ', '鳴る', 'ぱくつく', '留まる', '分ける', '籠っ', '踊ら', '持ちかけ', '伏し', '恐れ入り', '逢い', '許し', 'つらまえる', '奪い', 'ききつけ', '向う', '生', '食い殺さ', '書き入れ', '利か', '来よう', '鳴り立て', '附け', 'さがし出す', 'とまり', '出れ', '抜き取っ', '逢っ', '及ぼし', '亡くなっ', '分かれ', '呼びかけ', '済ん', '読め', '得る', '申し込も', '似合う', '奪い合っ', '疑わ', '逐っ', '嫌う', '強い', 'ぎっ', '着', 'とどめ', '舐める', '仕', '括っ', '叱りつける', 'ちょろまかし', '浮きあがる', '行け', '煮出し', '転がり', 'あばれ', '減ら', '突き出し', '近づく', '俯向い', '抜け', '歩い', '発し', '落ちつか', '出ろ', 'まくっ', '奉っ', '写し出す', '聞き返す', 'まぜ返し', '出せ', '投げ入れる', 'むける', '見つかれ', 'とりゃ', 'ととのう', 'とろう', 'のめり', '食える', '振れ', '凝り固まっ', 'え', 'いたたまれ', '着く', 'あつかい', '削り取ら', '引き下がっ', '兼ね', 'ひねくり', '押し通そう', '圧さ', '寄こし', '通り過ぎる', '切り落す', 'ころがり', '逃げ惑う', 'こし', '洗え', '申し上げ', '飲み込め', '提げ', '与えん', '登ら', '睨ま', 'わかれ', 'なす', '比べる', 'はやる', '云い放っ', '思い切っ', '振り立てる', '得れ', '釣っ', '佇ん', '申し立て', 'わから', '押し返し', 'かかえ', '取り扱っ', '心付い', 'くれれ', '振う', '奢る', '響き', '障っ', '出直す', '売り捌い', '鳴く', 'した ...

# %% [markdown]
# ## 32. 動詞の基本形
# 動詞の基本形をすべて抽出せよ.

# %%
verbs = {item["base"] for item in nlist if item["pos"] == "動詞"}
print(verbs)
# Out:
# {'済す', '居る', '引き上げる', '上す', '片付く', '襲う', '仰せる', '捉える', '涼む', '任ずる', '有る', '湧き出る', '結び付ける', '間違える', '立て籠もる', '度する', '潜る', '寝付く', '脱する', '入る', '罷り越す', '引き付ける', '取り去る', '交じる', '咲く', '遠ざかる', '刈る', '絡む', '迫り出す', '暮れ掛かる', '敗れる', '突っ伏す', '付ける', '祟る', '並み居る', '呈する', '寄せる', 'はぐる', '摘む', 'くっ付く', '御座る', '比する', '打ち返す', '犇めく', '立ち入る', '狼狽える', '起き上がる', '聞こえる', '紐解く', '捩じ上げる', '負う', '睨め付ける', '痩せる', '逸らす', '溺れる', '聞き出す', '抱く', '落ちる', '腐れる', '奪う', '垂れる', '見届ける', '争う', '流れ込む', '果たす', '転ずる', '見合わせる', 'のさばり出る', '刺し通す', '逃げ込む', '詰め寄せる', '跳ね返す', '響く', '食う', '説く', '回らす', '振れる', '絞る', '聞き質す', '扠置く', 'こせつく', '差し控える', '寝転ぶ', '煩わす', '化する', '引く-他動詞', '名乗る', '焦げる', '吹き通す', '切る', '振り落とす', '叱り付ける', '叱する', '踏み付ける', '熱する', '打つ', '滑らす', '並べ立てる', 'ぶら下げる', '伝わる', '聞き付ける', '仄めかす', '拭く', '写す', '捻る', '押し倒す', '弄する', '付け込む', '捻くる', '切り破る', '適う', '当て付ける', '垂らす', '欲する', '翳す', '弾く', '費やす', '刈り込む', '浮き上がる', '立てる', '寝過ごす', '付け加える', '講ずる', '弾き出す', '移る', '立ち止まる', '挑む', '燃える', '沸き上がる', '起こる', '温まる', '事足る', '傾く', '引っ繰り返す', '切らす', '擦る', '立て切る', '控える', '舞う', '回す', '追い払う', '荒らす', '決め付ける', '立ち行く', '催す', '陥れる', '弁じ立てる', '聳やかす', '煮出す', '持ち掛ける', '打ち留める', '張る', '罹る', '当たる', '飛び下りる', '使い分ける', '煎ずる', '詫び入る', 'へぐ', '打ち出す', '飽き足る', '浴びる', '閉じ籠もる', '引っ繰り返る', '吹き払う', '懲りる', '乱れ合う', '立ち返る', '疑る', '匂う', '送る', '剃る', '見放す', '振り掛ける', '祝う', '清める', '縊れる', '念ずる', '離れる', '守る', '括り付ける', '忍ぶ', '待ち受ける', '転がり落ちる', '正す', '混ぜ返す', '剥ぐ', '使う', '決める', '切り刻む', '読み掛ける', '鳴る', 'ぱくつく', '転げ落ちる', '見計らう', '分ける', '引き渡す', '盛り立てる', '突き込む', 'ふける', '得る', '似合う', '誤る', '組む', '嫌う', '免れる', '尖む', 'しゃがむ', '召す', 'ごろつく', '翻る', '踏ん張る', '彫る', '練る', '聞き返す', '投げ入れる', '奉ずる', '漲る', '噎せる', '着く', '捕まえる', '足りる', '通り過ぎる', '舐る', '逃げ惑う', '思い立つ', '逃れる', '決め込む', '連れ出す', '比べる', '押し立てる', '振り立てる', '報いる', '出直す', '鳴く', '言い合う', '悔やむ', '打ち殺す', '駆け込む', 'もがく', '障る', '打ち落とす', '痛む', '備わる', '打ち抜く', '固まる', '磨り潰す', '詫びる', '略す', '寝そべる', '誓う', '見習う', '灯る', '欲張る', '尽きる', '要る', '困らす', '並べる', '溶かす', '濡れる', '記する', '割り込む', '焦らせる', '整える', '満たす', '睨み合う', '忍ばす', '進める', '滅ぼす', '付き合う', '植える', '逝く', '燻り返る', '思い遣る', '入り込む', '這う', '漏る', '説き立てる', '捏ねる', '焦る', '出向く', '捜し出す', '伏す', 'のめる', '切り抜く', '行く', '置く', '読み飛ばす', '果せる', '惚ける', '称する', '組み合わせる', '呉れる', '生やす', '仰る', '下がる', '伝う', '巡らす', '俯く', '憂う', '取り上げる', '摩る', '取り出す', '縫い合わせる', '収める', '仕切る', '出来上がる', '描き出す', 'がたつく', '数え立てる', '衰える', '飲み干す', '待たす', '失せる', '沸かす', '嘗める', '吐く', '選る', '持ち直す', '引き裂く', '突き通す', '剥く', '震わせる', '外す', '仕舞い込む', '立ち掛ける', '待ち構える', '杓い上げる', '手子摺る', '落ち掛かる', '練り歩く', '追い回す', '重ねる', '綻びる', '吟ずる', '引っ掻く', '拵える', '灯す', '外れる', '書き上げる', '透かす', '記す', '取り扱う', '訳す', '凹ます', '施す', '食わす', '改める', '繰る', '挟む', '詰める', '暴く', '打ち付ける', '認める', '狂う', '包む', '除く', '仕入れる', '申し添える', '言い触らす', '紛う', '割り出す', '悩む', '言い掛ける', '取り立てる', '舞い込む', '望む', '利かす', '続く', '対する', '余る', '利く', '迫る', '噛み切る', '期する', '仰せ付ける', '背負う', '汚す', '積もる', '通り掛かる', '遂げる', '打ち入る', '責める', '行う', '養う', '笑い崩れる', '痛み入る', '脱ぐ', '接する', 'たでる', '揉む', '働く', '惚れ込む', '塗り消す', '塞がる', '込む', '喜ぶ', '慰む', '交ぜる', '溜める', '出る', '追い詰める', '穿る', '下す', '干す', '躍り込む', '静まり返る', '称える', '突く', '揃う', '張り付ける', '犯す', '暮らす', '叱る', '極まる', '吐き出す', '吸い込む', '唱える', '止す', '畳み込む', '拝する', '申し立てる', '来す', '思い付く', '射る', '投げ込む', '欠ける', '和する', '跳ね上がる', '省く', '解する', '見積もる', '嘯く', 'ひっぺがす', '押し掛ける', '著わす', '重なる', '睨め返す', '途切らす', '弱る', '出会う', '損なう', '振り向く', '処する', '染みる', '娶る', '下る', '勝つ', 'せしめる', '縮む', '捻り出す', '侮る', '見舞う', '志す', '迎える', '刻する', '至る', '落とす', '言わす', '読み出す', '零す', '差し込む', '撫でる', '引き比べる', '座る', '談ずる', '沿う', '放り込む', '気付く', '染み出す', '渡す', '明ける', '逆らう', '急く', '担ぎ出す', '結い巡らす', 'こじる', '過ぎ去る', '唆す', '魘される', 'くっ付ける', '終わる', '引き続く', '心得る', '浴する', '書き散らす', '鈍る', '退治る', '耽る', '向かい合う', '答える', '死ぬ', '言う', '叩き上げる', '明かす', 'あてがう', '流れる', '窶す', '解き捨てる', '損ずる', '隔たる', '崇める', '切り上げる', '於く', '弄る', '卜する', 'たくる', '剥き出す', '下さる', '隠れる', '着せる', '通り過ごす', '悟る', '苦しめる', '膨らむ', '救い出す', '図抜ける', '失う', '握る', '捨て置く', '仄めく', '塗り付ける', '歌う', '弾ける', '堪える', '呟く', '呼び掛ける', '包み込む', '立て通す', '為出かす', '吸い出す', '嗄れる', '振る', '飾る', '振り撒く', '力む', '出来る', '産する', '雇う', '彫り付ける', '覗く', 'しくじる', '引っ掛かる', '苦しむ', '泊まる', '出す', '冠する', '号する', '連れ添う', '巻き上げる', ' ...

# %% [markdown]
# ```{note}
# Currently writing...
# ```
