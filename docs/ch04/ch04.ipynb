# %% [markdown]
# # 第4章: 形態素解析
# 夏目漱石の小説『吾輩は猫である』の文章 ([neko.txt](https://nlp100.github.io/data/neko.txt)) をMeCabを使って形態素解析し, その結果をneko.txt.mecabというファイルに保存せよ. このファイルを用いて, 以下の問に対応するプログラムを実装せよ.
#
# なお, 問題37, 38, 39は[matplotlib](http://matplotlib.org/)もしくは[Gnuplot](http://www.gnuplot.info/)を用いるとよい.

# %% [markdown]
# ## 30. 形態素解析結果の読み込み
# 形態素解析結果 (neko.txt.mecab) を読み込むプログラムを実装せよ. ただし, 各形態素は表層形 (surface), 基本形 (base), 品詞 (pos), 品詞細分類1 (pos1) をキーとするマッピング型に格納し, 1文を形態素 (マッピング型) のリストとして表現せよ. 第4章の残りの問題では, ここで作ったプログラムを活用せよ.

# %%
import MeCab

mecab = MeCab.Tagger()
with open("neko.txt", "r") as f1, open("neko.txt.mecab", "w+") as f2:
    lines = f1.readlines()
    for text in lines:
        result = mecab.parse(text)
        f2.write(result)

# %%
with open("neko.txt.mecab", "r") as f:
    lines = f.readlines()
    nlist = []
    for text in lines:
        ndict = {}
        suf = text.split("\t")
        if suf[0] == "EOS":
            continue
        if len(suf) > 1:
            tmp = suf[1].split(",")
            ndict["surface"] = suf[0]
            if len(tmp) <= 7:
                ndict["base"] = suf[0]
            else:
                ndict["base"] = tmp[7]
            ndict["pos"] = tmp[0]
            ndict["pos1"] = tmp[1]
            nlist.append(ndict)
            
for item in nlist[:10]: # Due to file size constraints, the output is limited.
    print(item)
# Out:
# {'surface': '一', 'base': '一', 'pos': '名詞', 'pos1': '数詞'}
# {'surface': '\u3000', 'base': '\u3000', 'pos': '空白', 'pos1': ''}
# {'surface': '吾輩', 'base': '我が輩', 'pos': '代名詞', 'pos1': ''}
# {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'}
# {'surface': '猫', 'base': '猫', 'pos': '名詞', 'pos1': '普通名詞'}
# {'surface': 'で', 'base': 'だ', 'pos': '助動詞', 'pos1': ''}
# {'surface': 'ある', 'base': '有る', 'pos': '動詞', 'pos1': '非自立可能'}
# {'surface': '。', 'base': '。', 'pos': '補助記号', 'pos1': '句点'}
# {'surface': '名前', 'base': '名前', 'pos': '名詞', 'pos1': '普通名詞'}
# {'surface': 'は', 'base': 'は', 'pos': '助詞', 'pos1': '係助詞'}

# %% [markdown]
# ## 31. 動詞
# 動詞の表層形をすべて抽出せよ.

# %%
verbs = [item["surface"] for item in nlist if item["pos"] == "動詞"]
print(verbs)
# Out:
# ['ある', '生れ', 'つか', 'し', '泣い', 'い', 'し', 'いる', '始め', 'いう', '見', '聞く', 'いう', 'あっ', 'いう', '捕え', '煮', '食う', 'いう', 'ある', 'いう', '思わ', '載せ', '持ち上げ', 'し', 'あっ', 'ある', '落ちつい', '見', 'いう', '見', 'あろう', '思っ', '残っ', 'いる', 'もっ', 'さ', 'し', '逢っ', '出会わし', 'し', 'いる', 'し', '吹く', '咽せ', '弱っ', '飲む', 'いう', 'ある', '知っ', '坐っ', 'おっ', 'する', 'し', '始め', '動く', '動く', '分ら', '廻る', 'なる', '助から', '思っ', 'いる', 'し', '出', 'し', 'いる', '考え出そう', 'し', '分ら', '付い', '見る', 'い', 'おっ', '見え', '隠し', 'しまっ', '違っ', '明い', 'い', '這い出し', '見る', '棄て', 'ある', '這い出す', 'ある', '坐っ', 'し', '考え', '見', 'いう', '出', 'し', '泣い', '来', 'くれる', '考え付い', 'やっ', '見', '来', '渡っ', '暮れかかる', '減っ', '来', '泣き', '出', 'ある', 'ある', 'し', '廻り', '始め', 'し', '這っ', '行く', '出', '這入っ', 'なる', '思っ', '崩れ', 'もぐり込ん', '破れ', 'い', 'し', '知れ', 'ある', '云っ', '至る', 'する', 'なっ', 'いる', '忍び込ん', 'し', '分ら', 'なる', '減る', 'し', '降っ', '来る', 'いう', '出来', 'なっ', 'あるい', '行く', '考える', '這入っ', 'おっ', '見る', 'し', 'ある', '逢っ', 'ある', '見る', 'つかん', '抛り出し', '思っ', 'ねぶっ', '任せ', 'い', 'し', '出来', '見', '這い上っ', 'する', '投げ出さ', '投げ出さ', '這い上り', '這い上っ', '投げ出さ', '繰り返し', 'し', 'いる', '云う', 'なっ', '偸ん', 'し', 'やっ', '下り', 'つまみ出さ', 'し', 'いい', '出', '来', 'ぶら下げ', '向け', '出し', '出し', '上っ', '来', '困り', 'いう', '撚り', '眺め', 'おっ', '置い', 'やれ', 'いっ', '這入っ', 'しまっ', '聞か', '見え', '抛り出し', 'し', '極める', 'し', 'ある', '合せる', '帰る', '這入っ', '出', '来る', '思っ', 'いる', 'ある', '見せ', 'いる', 'いう', '覗い', '見る', 'し', 'いる', 'ある', '読みかけ', 'ある', 'たらし', 'いる', '帯び', 'あらわし', 'いる', '食う', '食っ', '飲む', '飲ん', 'ひろげる', '読む', 'なる', '垂らす', '繰り返す', 'ある', '考える', 'ある', 'いう', '生れ', 'なる', '限る', '寝', 'い', '勤まる', '出来', '云わ', '来る', '鳴らし', 'いる', '住み込ん', 'あっ', '行っ', '付け', 'し', 'さ', '至る', 'つけ', 'くれ', '分る', '出来', '得る', '入れ', 'くれ', 'いる', 'つとめ', '読む', '乗る', 'する', '乗る', 'いう', '構い', 'やむ', '得ん', 'ある', '寝る', 'し', '入っ', 'もぐり込ん', 'ねる', 'ある', 'いう', 'なる', '入っ', '寝る', '容る', '見出し', '割り込む', 'ある', '醒ます', 'なる', '来', '来', 'いっ', '泣き', '出す', 'ある', 'する', 'さまし', '飛び出し', 'くる', '叩か', 'し', 'すれ', 'する', 'せ', '得', 'なっ', 'する', '至っ', 'ある', 'し', 'かぶせ', '抛り出し', '押し込ん', 'する', 'しよう', '追い廻し', '加える', '磨い', '怒っ', '入れ', '顫え', 'い', 'ある', 'する', '逢う', '言っ', 'おら', '産まれ', 'ある', '持っ', '行っ', '棄て', '来', '流し', '話し', 'し', 'し', 'する', '戦っ', 'せ', 'なら', 'いわ', '思う', 'いう', '解し', 'い', 'いっ', 'し', 'いる', '見付け', '食う', 'ある', 'なっ', 'いる', '守ら', '訴え', 'しかる', '見え', '見付け', 'せ', 'ある', '頼ん', '食い', '得', '奪っ', 'すまし', 'いる', 'おり', '持っ', 'いる', '住ん', 'いる', '関する', 'ある', 'かこう', '送ら', '栄える', 'ある', '待つ', '思い出し', 'し', 'しよう', 'いっ', '勝れ', '出来る', '出し', 'やっ', 'し', '出し', 'かい', 'よる', '凝っ', '習っ', '鳴らし', 'する', 'なっ', 'おら', 'やり', '出す', 'うたっ', 'つけ', 'いる', '関せ', '繰返し', 'いる', '吹き出す', 'ある', 'いう', 'なっ', '住み込ん', 'ある', '提げ', '帰っ', '来', '買っ', '来', '思う', 'いう', 'やめ', 'かく', '見え', 'いう', 'し', 'かい', 'いる', 'かき上げ', '見る', 'かい', 'つか', '思っ', 'やっ', 'いる', '来', 'し', 'いる', '聞い', 'かけ', '見る', 'とっ', '見る', '感ずる', 'ある', '見', 'かけ', 'かける', 'し', '言っ', 'ある', 'かく', '写せ', '飛ぶ', '走る', 'かこう', '思う', 'し', 'いっ', 'ある', '知ら', 'し', 'いる', '嘲ける', '見え', '出', 'し', 'い', '出', '来', 'やっ', 'いる', '覚め', 'し', 'いる', 'あけ', '見る', '極め込ん', 'いる', '見', '覚え', 'する', '禁じ', '得', 'せ', 'し', 'し', 'ある', 'ある', '寝', 'し', 'たまら', '執っ', 'いる', '動い', '思っ', 'し', 'おっ', 'かき上げ', 'いる', 'する', 'し', 'いいあえ', '勝る', '思っ', 'おら', '描き出さ', 'ある', 'し', '思わ', '違う', '含める', '有し', 'いる', '見', '疑う', '思う', 'しかる', '見る', '交ぜ', 'ある', 'いう', '評し', 'ある', '寝', 'いる', 'し', '見え', '寝', 'いる', 'し', 'ある', '思っ', 'せ', '得', '動か', 'におっ', 'やり', '思っ', 'し', 'いる', 'する', '出来', 'なっ', 'やむ', 'え', 'し', 'し', '押し出し', 'し', 'なっ', '見る', 'し', 'い', '打ち', 'わし', '行っ', '足そう', '思っ', '這い出し', 'する', '掻き', '交ぜ', 'し', '怒鳴っ', '罵る', 'いう', 'ある', '言い', '知ら', 'し', '知ら', '思う', '乗る', 'する', '甘んじ', '受ける', 'なる', 'し', 'くれ', '立っ', 'いう', '慢じ', 'し', 'いる', '出', '来', '窘め', 'やら', 'する', '分ら', 'する', 'つい', '悲しむ', 'し', 'ある', 'ある', 'し', '当る', '騒い', '出来', '出', '養う', 'ある', 'あっ', 'し', '運ば', '嗅ぎ', 'くる', '押し倒し', '寝', 'いる', '近づく', '心付か', '心付く', 'なる', 'し', '眠っ', 'いる', '忍び入り', 'かく', '睡ら', '驚か', '得', 'ある', '過ぎ', '抛げ', 'かけ', 'する', '見え', '燃え', '思わ', '云う', '有し', 'いる', 'ある', '忘れ', 'し', '眺め', 'いる', '出', '誘っ', '落ち', '開い', 'し', 'いる', 'する', 'いう', '輝い', 'い', 'し', '射る', 'あつめ', '云っ', 'し', '思っ', 'し', '籠っ', 'いる', '抱い', 'し', '思っ', 'あ ...

# %% [markdown]
# ## 32. 動詞の基本形
# 動詞の基本形をすべて抽出せよ.

# %%
verbs = [item["base"] for item in nlist if item["pos"] == "動詞"]
print(verbs)
# Out:
# ['有る', '生まれる', '付く', '為る', '泣く', '居る', '為る', '居る', '始める', '言う', '見る', '聞く', '言う', '有る', '言う', '捕らえる', '煮る', '食う', '言う', '有る', '言う', '思う', '乗せる', '持ち上げる', '為る', '有る', '有る', '落ち着く', '見る', '言う', '見る', '有る', '思う', '残る', '居る', '持つ', '為る', '為る', '会う', '出会わす', '為る', '居る', '為る', '吹く', '噎せる', '弱る', '飲む', '言う', '有る', '知る', '座る', '居る', '為る', '為る', '始める', '動く', '動く', '分かる', '回る', '成る', '助かる', '思う', '居る', '為る', '出る', '為る', '居る', '考え出す', '為る', '分かる', '付く', '見る', '居る', '居る', '見える', '隠す', '仕舞う', '違う', '明く', '居る', '這い出す', '見る', '捨てる', '有る', '這い出す', '有る', '座る', '為る', '考える', '見る', '言う', '出る', '為る', '泣く', '来る', '呉れる', '考え付く', '遣る', '見る', '来る', '渡る', '暮れ掛かる', '減る', '来る', '泣く', '出る', '有る', '有る', '為る', '回る', '始める', '為る', '這う', '行く', '出る', '入る', '成る', '思う', '崩れる', '潜り込む', '破れる', '居る', '為る', '知れる', '有る', '言う', '至る', '為る', '成る', '居る', '忍び込む', '為る', '分かる', '成る', '減る', '為る', '降る', '来る', '言う', '出来る', '成る', '歩く', '行く', '考える', '入る', '居る', '見る', '為る', '有る', '会う', '有る', '見る', '掴む', '放り出す', '思う', '舐る', '任せる', '居る', '為る', '出来る', '見る', '這い上る', '為る', '投げ出す', '投げ出す', '這い上る', '這い上る', '投げ出す', '繰り返す', '為る', '居る', '言う', '成る', '盗む', '為る', '遣る', '下りる', '撮み出す', '為る', '言う', '出る', '来る', 'ぶら下げる', '向ける', '出す', '出す', '上る', '来る', '困る', '言う', '縒る', '眺める', '居る', '置く', '遣る', '言う', '入る', '仕舞う', '聞く', '見える', '放り出す', '為る', '極める', '為る', '有る', '合わせる', '返る', '入る', '出る', '来る', '思う', '居る', '有る', '見せる', '居る', '言う', '覗く', '見る', '為る', '居る', '有る', '読み掛ける', '有る', '垂らす', '居る', '帯びる', '表わす', '居る', '食う', '食う', '飲む', '飲む', '広げる', '読む', '成る', '垂らす', '繰り返す', '有る', '考える', '有る', '言う', '生まれる', '成る', '限る', '寝る', '居る', '勤まる', '出来る', '言う', '来る', '鳴らす', '居る', '住み込む', '有る', '行く', '付ける', '為る', '為る', '至る', '付ける', '呉れる', '分かる', '出来る', '得る', '入れる', '呉れる', '居る', '勤める', '読む', '乗る', '為る', '乗る', '言う', '構う', '止む', '得る', '有る', '寝る', '為る', '入る', '潜り込む', '練る', '有る', '言う', '成る', '入る', '寝る', '容れる', '見出だす', '割り込む', '有る', '覚ます', '成る', '来る', '来る', '言う', '泣く', '出す', '有る', '為る', '覚ます', '飛び出す', '来る', '叩く', '為る', '為る', '為る', '為る', '得る', '成る', '為る', '至る', '有る', '為る', '被せる', '放り出す', '押し込む', '為る', '為る', '追い回す', '加える', '磨く', '怒る', '入れる', '震える', '居る', '有る', '為る', '会う', '言う', '居る', '生まれる', '有る', '持つ', '行く', '捨てる', '来る', '流す', '話す', '為る', '為る', '為る', '戦う', '為る', '成る', '言う', '思う', '言う', '解する', '居る', '言う', '為る', '居る', '見付ける', '食う', '有る', '成る', '居る', '守る', '訴える', '然る', '見える', '見付ける', '為る', '有る', '頼む', '食う', '得る', '奪う', '澄ます', '居る', '居る', '持つ', '居る', '住む', '居る', '関する', '有る', '掻く', '送る', '栄える', '有る', '待つ', '思い出す', '為る', '為る', '言う', '取る', '出来る', '出す', '遣る', '為る', '出す', '掻く', '因る', '凝る', '習う', '鳴らす', '為る', '成る', '居る', '遣る', '出す', '歌う', '付ける', '居る', '関する', '繰り返す', '居る', '吹き出す', '有る', '言う', '成る', '住み込む', '有る', '下げる', '返る', '来る', '買う', '来る', '思う', '言う', '止める', '掻く', '見える', '言う', '為る', '掻く', '居る', '書き上げる', '見る', '掻く', '付く', '思う', '遣る', '居る', '来る', '為る', '居る', '聞く', '掛ける', '見る', '取る', '見る', '感ずる', '有る', '見る', '掛ける', '掛ける', '為る', '言う', '有る', '掻く', '写す', '飛ぶ', '走る', '掻く', '思う', '為る', '言う', '有る', '知る', '為る', '居る', '嘲る', '見える', '出る', '為る', '居る', '出る', '来る', '遣る', '居る', '覚める', '為る', '居る', '開ける', '見る', '決め込む', '居る', '見る', '覚える', '為る', '禁ずる', '得る', '為る', '為る', '為る', '有る', '有る', '寝る', '為る', '堪る', '取る', '居る', '動く', '思う', '為る', '居る', '書き上げる', '居る', '為る', '為る', '言い合う', '勝る', '思う', '居る', '描き出す', '有る', '為る', '思う', '違う', '含める', '有する', '居る', '見る', '疑う', '思う', '然る', '見る', '交ぜる', '有る', '言う', '評する', '有る', '寝る', '居る', '為る', '見える', '寝る', '居る', '為る', '有る', '思う', '為る', '得る', '動く', '匂う', '遣る', '思う', '為る', '居る', '為る', '出来る', '成る', '止む', '得る', '為る', '為る', '押し出す', '為る', '成る', '見る', '為る', '居る', '打つ', '和する', '行く', '足す', '思う', '這い出す', '為る', '掻く', '交ぜる', '為る', '怒鳴る', '罵る', '言う', '有る', '言う', '知る', '為る', '知る', '思う', '乗る', '為る', '甘んずる', '受ける', '成る', '為る', '呉れる', '立つ', '言う', '慢ずる', '為る', '居る', '出る', '来る', '窘める', '遣る', '為る', '分かる', '為る', 'つく', '悲しむ', '為る', '有る', '有る', '為る', '当たる', '騒ぐ', '出来る', '出る', '養う', '有る', '有る', '為る', '運ぶ', '嗅ぐ', '来る', '押し倒す', '寝る', '居る', '近付く', '心付く', '心付く', '成る', '為る', '眠る', '居る', '忍び入る', '掻く', '眠る', '驚く', '得る', '有る', '過ぎる', '投げる', '掛ける', '為る', '見える', '燃える ...

# %% [markdown]
# ```{note}
# Currently writing...
# ```
